# %% [markdown]
# ### Final project of course five of the IBM Machine Learning Profesional Certificate with Coursera.

# %%
from IPython.display import Image

# %% [markdown]
# ### 1. About the Dataset

# %% [markdown]
# This dataset contains information about customer of a telecom company, which includes demographics, service subscriptions, billing information, and churn status. It captures aspects like hether a customer has phone or internet services, their tenure with the company, usage of additional services like online security, and their chosen payment methods as features that would be learning to decide if a customer churned or not. This dataset is particularly useful in analyzing patterns and factors that contribute to customer churn. However, our focus would be on predictivity instead of interpretability, though this may be more useful for business purpose than our choice.

# %% [markdown]
# ### 2. Objectives.

# %% [markdown]
# By the end of this notebook, we would build the following models.
# + A simple LogisticsRegression
# + A Mullti-Layer perceptron Classifier
# + Use RandomizeCV to search for optimal params for the MLPClassifier
# + A deep neural network to find out which one performs the best.

# %% [markdown]
# ### 3. Models.

# %% [markdown]
# #### Model1: LogisticRegression.

# %% [markdown]
# ##### The table below is a randomly selected sample of the actual classes and the predicted classes of a dataset by the LogisticRegression algorithm.

# %%
Image("/Users/marcelgrossmann/Documents/Project/MLCoursera/Dataset/pred_model1.png")

# %% [markdown]
# From the table above, we can see that there is a mixed up at index 5760. 0 indicates that the customer did not churn and 1 indicates that the customer churned.

# %%
Image("/Users/marcelgrossmann/Documents/Project/MLCoursera/Dataset/cm_model1.png")

# %% [markdown]
# The matrix above shows the ground truth value(along the vertical axis) vs the predicted values(along the horizontal axis). the diagonal 0.9 - 0.54 represence true positive and true negatives respectfully whereas 0.1 - 0.46 represence false positive and false negative respectfully.

# %% [markdown]
# #### Error matrics

# %%
Image("/Users/marcelgrossmann/Documents/Project/MLCoursera/Dataset/metric-model1.png")

# %%
Image("/Users/marcelgrossmann/Documents/Project/MLCoursera/Dataset/ROC_model1.png")

# %% [markdown]
# The curve above is and Receiver-Operating Characteristic curve(ROC) which plots the true positive against the false positive rate of the binary classifier churn vs not churn.
# The Receiver-Operating Characteristic Curve Area Under the Curve(ROC AUC) score is a single value that indicates how well the binary classifier performed. This score ranges from 0 to 1 with 0 being the worst performance, 0.5 being a random performance and 1 being the best performance.

# %% [markdown]
# ##### Model2

# %% [markdown]
# ##### The table below is a randomly selected sample of the actual classes and the predicted classes of a dataset by the a Multi-Layer Perceptron Classifier.

# %%
Image("/Users/marcelgrossmann/Documents/Project/MLCoursera/Dataset/mutl_pred.png")

# %%
Image("/Users/marcelgrossmann/Documents/Project/MLCoursera/Dataset/cm_model2.png")

# %%
Image("/Users/marcelgrossmann/Documents/Project/MLCoursera/Dataset/error_met2.png")

# %%
Image("/Users/marcelgrossmann/Documents/Project/MLCoursera/Dataset/ROC_model2.png")

# %% [markdown]
# The larger the area under the curve above, the better the model did in classifying customers into two group churn(1)and not churn(0).

# %% [markdown]
# #### Model3

# %% [markdown]
# ### Insights and key findings.

# %% [markdown]
# ### 4. Nextsteps
