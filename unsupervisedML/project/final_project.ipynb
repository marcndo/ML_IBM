# %%
from IPython.display import Image

# %% [markdown]
# ### About the data set

# %% [markdown]
# The dataset 2126 measurements extracted from cardiotocograms and classified by expert obstetricians into the following classes.
# * Normal
# * Suspect
# * Pathological
# + This dataset is made up of 22 features all of which are floats.

# %% [markdown]
# ### Objectives.

# %% [markdown]
# By the end of this notebook, we would build three different models that classify the data set.
# * K-Means without PCA.
# * K-Means with PCA.
# * DBSCAN
# * We would then measure their performance and see which one does a better job in clustering the dataset

# %% [markdown]
# ### Models

# %% [markdown]
# #### 1. K-Means without clustering

# %% [markdown]
# Below is a graph of inertia versus number of clusters.This graph does not give a clear elbow point for us to decide the number of clusters that gives the best performance.

# %%
Image("/Users/marcelgrossmann/Documents/Project/MLCoursera/Dataset/kmeans.png")

# %% [markdown]
# Since from the data set we were given a clue that the dataset has three different classes, we consider number of clusters to be three. Based on this, we have the following classifications as indicated in the kmeans column.

# %%
Image("/Users/marcelgrossmann/Documents/Project/MLCoursera/Dataset/kmean-clusters.png")

# %% [markdown]
# Based on the table below we see that
# * 1.0 from the fetal_health column of the data set represence 0.
# * 2.0 is represented by 3.
# * 3.0 is represented by 2.

# %%
Image("/Users/marcelgrossmann/Documents/Project/MLCoursera/Dataset/pca-kmean.png")

# %% [markdown]
# #### 2. KMeans with PCA.

# %%
Image("/Users/marcelgrossmann/Documents/Project/MLCoursera/Dataset/pca-kmeans.png")

# %%
Image("/Users/marcelgrossmann/Documents/Project/MLCoursera/Dataset/pca-kmean-label.png")

# %% [markdown]
# Based on the table below we see that
# * 1.0 from the fetal_health column of the data set represence 0.
# * 2.0 is represented by 3.
# * 3.0 is represented by 2.

# %% [markdown]
# #### 3. DBSCAN

# %%
Image("/Users/marcelgrossmann/Documents/Project/MLCoursera/Dataset/dbscan.png")

# %% [markdown]
# The from the table below, we can see that DBSCAN creates serveral more clusters than expected. Thus DBSCAN does a poor job in this case compared to the KMeans.

# %%
Image("/Users/marcelgrossmann/Documents/Project/MLCoursera/Dataset/dbscan-labels.png")

# %% [markdown]
# ### Key points.

# %% [markdown]
# + DBSCAN creates more clusters than expected.
# + DBSCAN also indicates the presence of serveral outliers(-1) in the dataset.
# + KMeans does a better job in this case compared to DBSCAN.
# + Applying PCA did not hugely help KMean in clustering the data points.

# %% [markdown]
# ### Furture actions.

# %% [markdown]
# + Investigating with other clustering algorithms like Hierarchical clustering, Agglomerative clustering.
# + Engineering the features could also help.
